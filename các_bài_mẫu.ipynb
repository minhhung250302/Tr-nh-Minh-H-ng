# %% [markdown]
# <a href="https://colab.research.google.com/github/minhhung250302/Tr-nh-Minh-H-ng/blob/main/c%C3%A1c_b%C3%A0i_m%E1%BA%ABu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('text.txt',mode='w') as accounts :
 accounts.write('1 Nguyen Van A 8.0\n')
 accounts.write('2 Le Thi B 6.8\n')

# %%
# -*- coding: utf-8 -*-

with open('text.txt',mode='w') as accounts :
 accounts.write('1 Nguyen Van A 8.0\n')
 accounts.write('2 Le Thi B 6.8\n')

from openpyxl import Workbook
wb = Workbook()
sheet=wb.active
sheet['A1']='Tran Van Hau'
sheet['B1']= '20104027'
sheet['A2']= 'Le Quang Trieu'
sheet['B2']= '20104056'
wb.save('test.xlsx')

"""2 """

import pandas as pd

dataframe = pd.read_csv('/content/test.xlsx')
dataframe(10)

with open('text.txt',mode='w') as accounts :
  print('7:00 BgytebVab A',file=accounts)
  print('7:01 BgytebVab B',file=accounts)

with open('text.txt',mode='r') as accounts :
  print(f'{"name":<20}{"score":<20}')
  for record in accounts:
    name,score = record.split()
    print(f'{name:<20}{score:>20}')

import pandas as pd
dataframe=pd.DataFrame()
dataframe['Name']=['Nguyen Van A','Le Thi B']
dataframe['student IP']=[20104001,20104003]
dataframe['score']=[8.0,9.0]
dataframe

"""show số giá trị head() tính từ đầu bảng"""

import pandas as pd
url = '/Dulieubai2.csv'
dataframe = pd.read_csv(url)
dataframe.head(7)

"""lọc xuất giá trị từ vị trí 3 đến 8"""

import pandas as pd
url = '/Dulieubai2.csv'
dataframe = pd.read_csv(url)
dataframe.iloc[2:8]

"""đọc từ đầu đến giá trị thứ 7"""

import pandas as pd
url = '/Dulieubai3.csv'
dataframe = pd.read_csv(url)
dataframe[:7]

"""lọc theo tên"""

import pandas as pd
url = '/Book4.csv'
dataframe = pd.read_csv(url)
dataframe.head(10)
dataframe[dataframe['khoa'] == 'CKM'].head(3)

"""xóa cột5cột5

"""

import pandas as pd
dataframe = pd.read_csv('/content/Book4.csv')
dataframe.drop('ho va ten',axis=1)

"""lệnh nhóm"""

import pandas as pd
dataframe = pd.read_csv('/content/Book4.csv')
dataframe.groupby('khoa').mean()

import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data

import pandas as pd
url = 'http://winterolympicsmedals.com/medals.csv'
data = pd.read_csv(url)
data.groupby('Medal').mean()

"""mở với file execl (openpyxl)

Ghi vào file(cách truy xuất 1, gán thẳng địa chỉ)
"""

from openpyxl import Workbook 
wb = Workbook()
Sheet = wb.active
Sheet['A1'] = 'Nguyen Van A'
Sheet['B1'] = '20104001'
Sheet['A2'] = 'Le Thi B'
Sheet['B2'] = '20104002'
Sheet['A3'] = 'Tran Van Quoc'
Sheet['A4'] = 'Phạm Ngọc C'
Sheet['B3'] = '20104003'
Sheet['B4'] = '20104004'
wb.save('test.xlsxx')

"""đọc file(cách truy xuất 2, đưa tọa độ)"""

import openpyxl
wb = openpyxl.load_workbook('test.xlsx')
Sheet = wb.active
t1 = Sheet['A1']
t2 = Sheet['B1']
t3 = Sheet.cell(row=2,column=1)
t4 = Sheet.cell(row=2,column=2)
t5 = Sheet['A3']
t6 = Sheet['B3']
print(t1.value,t2.value)
print(t3.value,t4.value)
print(t5.value,t6.value)

"""P/s: ghi file nào đọc file đó, phải ghi phải file trước khi đọc thì mới đọc file được . """

import openpyxl 
t1 = openpyxl.Workbook()
t2 = t1.active
c1 =t2.cell(row=1,column=1)
c1.value="Đặng Trí Dũng"
c2 = t2.cell(row=1,column=2)
c2.value= "Trịnh Đức Cường"
c3= t2['A2']
c3.value = "Ulsan"
c4= t2['B2']
c4.value="Genovoa"
t1.save('Hung.xlsx')

"""Phần ĐỒ HỌA

sử dụng 2 câu lệnh chính:
import matplotlib.pyplot as plt
import numpy as np
"""

import matplotlib.pyplot as plt
import numpy as np
x = np.arange(6)
y = x+1 
plt.plot(x , y ,'o--')
plt.show()

import matplotlib.pyplot as plt
import numpy as np
plt.plot(x,y,'o--')
plt.plot(x,-y,'o-')
plt.show()

import matplotlib.pyplot as plt
import numpy as np
plt.plot(x,y,'o--')
plt.plot(x,-y,'o-')
plt.title('y=x và y=-x')
plt.xlabel('x')
plt.ylabel('y)
plt.show()
#xóa trục tung hoàh(bỏ 3 dòng trước đó)
plt.axis('off')

import matplotlib.pyplot as plt
import numpy as np
N=16
x = np.linspace(0,15,16)
y=x
plt.plot(x,y,'o--')
plt.axis('off')
plt.show()

import matplotlib.pyplot as plt
import numpy as np
N = 16
x = np.linspace(0,15,16)
y = np.logspace(0.1,2,16)
plt.plot(x,y,'o--')
plt.show()

import matplotlib.pyplot as plt
import numpy as np
x = [4,5,3,1,6,7]
plt.plot(x)
plt.show()

import matplotlib.pyplot as plt
import numpy as np
x=np.arange(25)
plt.plot(x)
plt.show()

from numpy.ma.core import arange
import matplotlib.pyplot as plt
import numpy as np
x= np.arange(50)
plt.plot(x,x**3+1)
plt.show()

import matplotlib.pyplot as plt
import numpy as np
x = np.arange(7)
plt.plot(x,-x**2)
plt.plot(x,-x**3)
plt.plot(x,-2*x)
plt.plot(x,-2**x)
plt.show()

"""hoặc:

"""

import matplotlib.pyplot as plt
import numpy as np
x = np.arange(7)
plt.plot(x,-x==2, x,-x**3, x,-2*x, x,-2**x)
plt.show()

"""vẽ lưới"""

import matplotlib.pyplot as plt
import numpy as np
x = np.arange(7)
plt.plot(x,-x==2, x,-x**3, x,-2*x, x,-2**x)
plt.grid(True)
plt.savefig('test.png')
plt.show()

"""plt.plot(x,x**2,'--)
Chú thích:
x: giá trị trục x
x**2: giá trị trục y
'--' : nét vẽ của biểu đồ có thể thay đổi như o- ,o--,--,.-,.- , v.v

"""

import matplotlib.pyplot as plt
import numpy as np
x = arange(3)
plt.subplots_adjust(wspace=0.3,hspace=0.3)
plt.subplot(2,2,1) #số đầu tiên là hàng, số tiếp theo là cột và số cuối cùng là phần tử tác động.
plt.plot(x,-x**2, color='g')
plt.subplot(2,2,2)
plt.plot(x,-x**3, color='r')
plt.subplot(2,2,3)
plt.plot(x,-2*x,color='b')
plt.subplot(2,2,4)
plt.plot(x,-2**x,'o--')
plt.show()

import matplotlib.pyplot as plt
import numpy as np
plt.axis([0,200,0,400])
plt.scatter(60,350,s=1000,color='b',alpha=1)
plt.scatter(80,300,s=1000,color='y',alpha=.5)
plt.scatter(100,250,s=1000,color='r',alpha=.5)

import matplotlib.pyplot as plt
import numpy as np
plt.plot([70,50],[60,40], linewidth = 5,color='r')
plt.text(80,90,'text')

"""code thiếu"""

import matplotlib.pyplot as plt
import numpy as np
plt.axis([0,20, 0,20])
plt.arrow(8,2,-6,5, head_length=4, head_width=2, color='g')
plt.show()

"""vẽ dạng biểu đô cột"""

import matplotlib.pyplot as plt
import numpy as np
x = np.arange(4)
y = np.random.rand(4)
plt.bar(x,y)
plt.show()

import matplotlib.pyplot as plt
import numpy as np
y= np.random.rand(3,4)
plt.bar(x+0,y[0],color='b',width=0.25)
plt.bar(x+0.25,y[1],color='g',width=0.25)
plt.bar(x+0.5,y[2],color='r',width=0.25)
plt.show()

import matplotlib.pyplot as plt
import numpy as np
x= np.arange(4)
y = np.random.rand(4)
plt.barh(x,y)
plt.show()

import matplotlib.pyplot as plt
import numpy as np
N=1000
x= np.random.rand(N)
y=np.random.rand(N)
colors = np.random.rand(N)
size = 20
plt.scatter(x,y,s=size,c=colors,alpha=1)
plt.show()

# Commented out IPython magic to ensure Python compatibility.
import numpy as np
import skfuzzy as fuzz
import matplotlib.pyplot as plt
# %matplotlib inline
x=np.arange(30,80,0.1)
slow=fuzz.trimf(x,[30,30,50])
medium=fuzz.trimf(x,[30,50,70])
medium_fast=fuzz.trimf(x,[50,60,80])
full_speed=fuzz.trimf(x,[60,80,80])
plt.figure()
plt.plot(x,full_speed,'b',linewidth=1.5, label='Full Speed')
plt.plot(x,medium_fast,'k',linewidth=1.5, label='Medium Fast')
plt.plot(x,medium,'m',linewidth=1.5, label='Medium Powered')
plt.plot(x,slow,'r',linewidth=1.5, label='Slow')

import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl 
food = ctrl.Antecedent(np.arange (0,11,1), 'food')
service = ctrl.Antecedent(np.arange(0,11,1), 'service')
tip = ctrl.Consequent(np.arange(10,26,1), 'tip')
food['poor']= fuzz.trimf( food.universe, [0,0,5])
food['averange']=fuzz.trimf( food.universe,[0,5,10])
food['good']=fuzz.trimf( food.universe,[5,10,10])
service['poor']=fuzz.trimf( service.universe,[0,0,5])
service['averange']=fuzz.trimf( service.universe,[0,5,10])
service['good']=fuzz.trimf( service.universe,[5,10,10])
tip['less']=fuzz.trimf( tip.universe,[10,14,18])
tip['normal']=fuzz.trimf( tip.universe,[14,18,22])
tip['much']=fuzz.trimf( tip.universe,[18,22,25])
service.view()
food.view()
tip.view()

pip install scikit-fuzzy

import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl 
food = ctrl.Antecedent(np.arange (0,11,1), 'food')
service = ctrl.Antecedent(np.arange(0,11,1), 'service')
tip = ctrl.Consequent(np.arange(10,26,1), 'tip')
food['poor']= fuzz.trimf( food.universe, [0,0,5])
food['averange']=fuzz.trimf( food.universe,[0,5,10])
food['good']=fuzz.trimf( food.universe,[5,10,10])
service['poor']=fuzz.trimf( service.universe,[0,0,5])
service['averange']=fuzz.trimf( service.universe,[0,5,10])
service['good']=fuzz.trimf( service.universe,[5,10,10])
tip['less']=fuzz.trimf( tip.universe,[10,14,18])
tip['normal']=fuzz.trimf( tip.universe,[14,18,22])
tip['much']=fuzz.trimf( tip.universe,[18,22,25])
service.view()
food.view()
tip.view()

import pandas as pd
dataframe = pd.read_csv('/content/test.xlsxx')
dataframe.head()
